# %%
import pandas as pd

import sys

sys.path.append("../src")

from data_cleaning import clean_crime

clean_crime.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 import pandas as pd
# ----> 3 from data_cleaning import clean_crime
#       5 clean_crime.head()
#
# ModuleNotFoundError: No module named 'data_cleaning'
